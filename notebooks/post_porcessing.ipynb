# %%
import sys
# change the system path to the partent directory of the current file, so that we can import the QNN framework
sys.path.append("..")

# %%
import matplotlib.pyplot as plt
import pennylane as qp
from pennylane import numpy as np

import pandas as pd


from importlib import reload

# %%
import experiment_tracker
reload(experiment_tracker)
path = "../results/"

# %%
cost_history = experiment_tracker.load_costs(path=path)
df_costs = pd.DataFrame(cost_history)
df_costs
# Out:
#                             experiment_id step        cost
# 0    0c85391f-71e8-459e-a6b3-b05cccac7cd8    0  0.01714084
# 1    0c85391f-71e8-459e-a6b3-b05cccac7cd8    1  0.01565673
# 2    0c85391f-71e8-459e-a6b3-b05cccac7cd8    2  0.01510988
# 3    0c85391f-71e8-459e-a6b3-b05cccac7cd8    3  0.01121413
# 4    0c85391f-71e8-459e-a6b3-b05cccac7cd8    4  0.00986933
# ..                                    ...  ...         ...
# 135  cdd2739d-4b7d-42ed-82a0-277e5dac1d13   65  0.00719621
# 136  cdd2739d-4b7d-42ed-82a0-277e5dac1d13   66  0.00695003
# 137  cdd2739d-4b7d-42ed-82a0-277e5dac1d13   67  0.00683074
# 138  cdd2739d-4b7d-42ed-82a0-277e5dac1d13   68  0.00724626
# 139  cdd2739d-4b7d-42ed-82a0-277e5dac1d13   69  0.00762873
#
# [140 rows x 3 columns]
